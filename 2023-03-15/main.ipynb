# %% [markdown]
# Carga de archivo movies

# %%
import pandas as pd
df = pd.read_csv("/Users/juanestebanzabaladaza/Desktop/ITM/repos/itm-modelamiento-simulacion/2023-03-15/datasets/movies.csv", sep=';')

# %% [markdown]
# Gráfica archivo movies

# %%
df.plot(kind='scatter', x='user_id', y='star_wars')
# Out:
# <Axes: xlabel='user_id', ylabel='star_wars'>

# %% [markdown]
# Carga de archivo customer

# %%
df2 = pd.read_csv("/Users/juanestebanzabaladaza/Desktop/ITM/repos/itm-modelamiento-simulacion/2023-03-15/datasets/customer_churn_model.txt")

# %% [markdown]
# Gráfica archivo customer

# %%
df2.plot(kind='scatter', x='Day Mins', y='Day Charge')
# Out:
# <Axes: xlabel='Day Mins', ylabel='Day Charge'>
